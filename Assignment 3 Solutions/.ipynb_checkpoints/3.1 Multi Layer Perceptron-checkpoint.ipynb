# %% [markdown]
# # Multi Layer Perceptron

# %%
# %%bash
#
# pip install jdc
# Out:
# Requirement already satisfied: jdc in /home/nbcommon/anaconda3_431/lib/python3.6/site-packages

# %%
# Library imports
import random
import numpy as np
import jdc
import sklearn
from datasets import *

# %% [markdown]
# We define a generic neural network architecture as a python class which we would use in multiple exercies. You might want to revisit the tutorial notebook for a quick refresher on python classes.
#
# **Note:** We are using jdc to define each method of `class Network` in seperate cells. jdc follows the following syntax,
#
# ```py
# %%add_to #CLASS_NAME#
# def dummy_method(self):
# ```

# %%
class Network(object):

    def __init__(self, sizes):
        """The list ``sizes`` contains the number of neurons in the
        respective layers of the network. For example, if the list
        was [2, 3, 1] then it would be a three-layer network, with the
        first layer containing 2 neurons, the second layer 3 neurons,
        and the third layer 1 neuron."""
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.initialize_biases()
        self.initialize_weights()

# %% [markdown]
# # Initialization
#
# ## 3.1.1 Initialize weights and biases
#
# The biases and weights for the network are initialized randomly, using a Gaussian
# distribution with mean 0, and variance 1. Note that the first layer is assumed to be an input layer, and by convention we won't set any biases for those neurons, since biases are only ever used in computing the outputs from later layers. Implement the following functions to initialize biases and weights.
#
# **Hints:**
# ![](https://www.researchgate.net/profile/Michael_Frish/publication/241347660/figure/fig3/AS:298690993508361@1448224890429/Figure-3-The-structure-of-a-multilayer-perceptron-neural-network.png)
# - Since we do not define biases for input layer, `len(self.biases)` array is equal to `len(self.sizes) - 1`.
# - Every consecutive pair of layers in network have a set of weights connecting them. Hence the `len(self.weights)` would also be `len(self.sizes) - 1` .
# - `np.random.randn` picks random variables form gaussian distribution.

# %%
# %%add_to Network
# def initialize_biases(self):
#     self.biases = [np.random.randn(y, 1) for y in self.sizes[1:]]

# %%
# %%add_to Network
# def initialize_weights(self):
#     self.weights = [np.random.randn(y, x)
#                     for x, y in zip(self.sizes[:-1], self.sizes[1:])]

# %% [markdown]
# # Training
#
# We shall implement backpropagation with stochastic mini-batch gradient descent to optimize our network.

# %%
# %%add_to Network
# def train(self, training_data, epochs, mini_batch_size, learning_rate):
#     """Train the neural network using gradient descent.
#     ``training_data`` is a list of tuples ``(x, y)``
#     representing the training inputs and the desired
#     outputs.  The other parameters are self-explanatory."""
#
#     # training_data is a list and is passed by reference
#     # To prevernt affecting the original data we use
#     # this hack to create a copy of training_data
#     # https://stackoverflow.com/a/2612815
#     training_data = list(training_data)
#
#     for i in range(epochs):
#         # Get mini-batches
#         mini_batches = self.create_mini_batches(training_data, mini_batch_size)
#
#         # Itterate over mini-batches to update pramaters
#         cost = sum(map(lambda mini_batch: self.update_params(mini_batch, learning_rate), mini_batches))
#
#         # Find accuracy of the model at the end of epoch
#         acc = self.evaluate(training_data)
#
#         print("Epoch {} complete. Total cost: {}, Accuracy: {}".format(i, cost, acc))

# %% [markdown]
# ## 3.1.2 Create mini-batches
#
# Split the training data into mini-batches of size `mini_batch_size` and return a list of mini-batches.

# %%
# %%add_to Network
# def create_mini_batches(self, training_data, mini_batch_size):
#     # Shuffling data helps a lot in mini-batch SGD
#     random.shuffle(training_data)
#     mini_batches = [training_data[k:k+mini_batch_size] for k in range(0, len(training_data), mini_batch_size)]
#     return mini_batches

# %% [markdown]
# ## 3.1.3 Update weights and biases
# <img src="https://docs.google.com/drawings/d/e/2PACX-1vQ-BdgJQ_h-W6cvgvdp5Bv_YiC_oMVQ7Tsz6kecQm4SRTE6Zq0HUKbEFCNDtBKNR9-YS_i104TCXPaE/pub?w=601&amp;h=259">
# P.S. Alpha is learning rate in case you still didn't get it :P

# %%
# %%add_to Network
# def update_params(self, mini_batch, learning_rate):
#     """Update the network's weights and biases by applying
#     gradient descent using backpropagation."""
#
#     # Initialize gradients
#     delta_b = [np.zeros(b.shape) for b in self.biases]
#     delta_w = [np.zeros(w.shape) for w in self.weights]
#
#     total_cost = 0
#
#     for x, y in mini_batch:
#         # Obtain the mean squared error and the gradients
#         # with resepect to biases and weights
#         cost, del_b, del_w = self.backprop(x, y)
#
#         # Add the gradients for each sample in mini-batch
#         delta_b = [nb + dnb for nb, dnb in zip(delta_b, del_b)]
#         delta_w = [nw + dnw for nw, dnw in zip(delta_w, del_w)]
#
#         total_cost += cost
#
#     # Update self.biases and self.weights
#     # using delta_b, delta_w and learning_rate
#     self.biases = [b - (learning_rate / len(mini_batch)) * db
#                    for b, db in zip(self.biases, delta_b)]
#     self.weights = [w - (learning_rate / len(mini_batch)) * dw
#                     for w, dw in zip(self.weights, delta_w)]
#
#     return total_cost

# %%
# %%add_to Network
# def backprop(self, x, y):
#     """Return arry containiing cost, del_b, del_w representing the
#     cost function C(x) and gradient for cost function.  ``del_b`` and
#     ``del_w`` are layer-by-layer lists of numpy arrays, similar
#     to ``self.biases`` and ``self.weights``."""
#     # Forward pass
#     zs, activations = self.forward(x)
#
#     # Backward pass
#     cost, del_b, del_w = self.backward(activations, zs, y)
#
#     return cost, del_b, del_w

# %% [markdown]
# ## 3.1.5 Implement functions to calculate sigmoid and it's derivative

# %%
# %%add_to Network
# def sigmoid(self, z):
#     """The sigmoid function."""
#     return 1.0 / (1.0 + np.exp(-z))

# %%
# %%add_to Network
# def sigmoid_derivative(self, z):
#     """Derivative of the sigmoid function."""
#     return self.sigmoid(z) * (1 - self.sigmoid(z))

# %% [markdown]
# ## 3.1.6 Implement forward propogration
#
# <img src="https://docs.google.com/drawings/d/e/2PACX-1vRu0-T4iRYiif9UAVgEia-fLPd2c0FB4EOO_AiQzLGAU1gBadvscWUpKMG533PTSTXVqcagukcbHOK3/pub?w=656&amp;h=370">

# %%
# %%add_to Network
# def forward(self, x):
#     """Compute Z and actiavtion for each layer."""
#
#     # list to store all the activations, layer by layer
#     zs = []
#
#     # current activation
#     activation = x
#     # list to store all the activations, layer by layer
#     activations = [x]
#
#     # Loop through each layer to compute activations and Zs
#     for b, w in zip(self.biases, self.weights):
#         # Calculate z
#         # watch out for the dimensions of multiplying matrices
#         z = np.dot(w, activation) + b
#         zs.append(z)
#         # Calculate activation
#         activation = self.sigmoid(z)
#         activations.append(activation)
#
#     return zs, activations

# %% [markdown]
# ## 3.1.7 Implement functions to calculate mean squared error and  it's derivative

# %%
# %%add_to Network
# def mse(self, output_activations, y):
#     """Returns mean square error."""
#     return sum((output_activations - y) ** 2 / 2)

# %%
# %%add_to Network
# def mse_derivative(self, output_activations, y):
#     """Return the vector of partial derivatives \partial C_x /
#     \partial a for the output activations. """
#     return (output_activations - y)

# %% [markdown]
# ## 3.1.8 Implement backward pass
#
# Refer [this](http://colah.github.io/posts/2015-08-Backprop/) blog by Christopher Olah to understand how gradient computation happens during backward pass.

# %%
# %%add_to Network
# def backward(self, activations, zs, y):
#     """Compute and return cost funcation, gradients for
#     weights and biases for each layer."""
#     # Initialize gradient arrays
#     del_b = [np.zeros(b.shape) for b in self.biases]
#     del_w = [np.zeros(w.shape) for w in self.weights]
#
#     # Compute for last layer
#     cost = self.mse(activations[-1], y)
#     delta = self.mse_derivative(activations[-1], y) * \
#             self.sigmoid_derivative(zs[-1])
#     del_b[-1] = delta
#     del_w[-1] = np.dot(delta, activations[-2].transpose())
#
#     # Loop through each layer in reverse direction to
#     # populate del_b and del_w
#     for l in range(2, self.num_layers):
#         z = zs[-l]
#         sp = self.sigmoid_derivative(z)
#         delta = np.dot(self.weights[-l + 1].transpose(), delta) * sp
#         del_b[-l] = delta
#         del_w[-l] = np.dot(delta, activations[-l -1].transpose())
#
#     return cost, del_b, del_w

# %%
# %%add_to Network
# def evaluate(self, test_data):
#     """Return the accuracy of Network. Note that the neural
#     network's output is assumed to be the index of whichever
#     neuron in the final layer has the highest activation."""
#     test_results = [(np.argmax(self.forward(x)[1][-1]), np.argmax(y))
#                     for (x, y) in test_data]
#     return sum(int(x == y) for (x, y) in test_results) * 100 / len(test_results)

# %% [markdown]
# # Showtime
#
# Let's test our implementation on a bunch of datasets.

# %%
datasets = generate_datsets()

plot_datasets(datasets)

# %%
def pre_process_data(x, y):
    # Find number samples     
    n = len(y)
    # Find number classes
    c  = max(y) + 1
    
    # Normalize the input     
    x = sklearn.preprocessing.normalize(x)

    x = np.split(x, n)
    x = [a.reshape(-1, 1) for a in x]
    
    # Convert lables to one-hot vectors     
    one_hot = np.zeros([n, c])
    one_hot[range(n), y] = 1
    
    y = np.split(one_hot, n)
    y = [a.reshape(-1, 1) for a in y]
    
    return list(zip(x, y))

# %% [markdown]
# ## 3.1.9 Try out different hyper-parameters

# %%
datasets_with_pred = {}

for name, dataset in datasets.items():
    
    print("Training dataset: {}".format(name))

    X, Y = dataset

    # Find number classes
    c  = max(Y) + 1
    
    # Pre-process the data
    # Checkout the implementation for some cool numpy tricks     
    training_data = pre_process_data(X, Y)
    
    network = Network([2, 7, c])
    
    network.train(training_data, 20, 10, 0.1)
    
    predictions = list(map(lambda sample: np.argmax(network.forward(sample[0])[1][-1]), training_data))
    
    datasets_with_pred[name] = X, Y, predictions
# Out:
# Training dataset: noisy_circles
# Epoch 0 complete. Total cost: [ 382.36414745], Accuracy: 50.0
# Epoch 1 complete. Total cost: [ 378.98854645], Accuracy: 49.6
# Epoch 2 complete. Total cost: [ 377.82664663], Accuracy: 50.2
# Epoch 3 complete. Total cost: [ 377.61422041], Accuracy: 49.6
# Epoch 4 complete. Total cost: [ 377.37648104], Accuracy: 49.6
# Epoch 5 complete. Total cost: [ 376.87730775], Accuracy: 50.13333333333333
# Epoch 6 complete. Total cost: [ 376.89538335], Accuracy: 50.2
# Epoch 7 complete. Total cost: [ 376.71286399], Accuracy: 49.333333333333336
# Epoch 8 complete. Total cost: [ 376.55987565], Accuracy: 49.733333333333334
# Epoch 9 complete. Total cost: [ 376.25793153], Accuracy: 50.4
# Epoch 10 complete. Total cost: [ 375.87104347], Accuracy: 50.0
# Epoch 11 complete. Total cost: [ 376.52213459], Accuracy: 49.8
# Epoch 12 complete. Total cost: [ 376.46771391], Accuracy: 49.8
# Epoch 13 complete. Total cost: [ 375.97499032], Accuracy: 49.8
# Epoch 14 complete. Total cost: [ 376.34568162], Accuracy: 49.53333333333333
# Epoch 15 complete. Total cost: [ 375.63368703], Accuracy: 49.8
# Epoch 16 complete. Total cost: [ 375.72620658], Accuracy: 50.06666666666667
# Epoch 17 complete. Total cost: [ 375.67051939], Accuracy: 49.733333333333334
# Epoch 18 complete. Total cost: [ 376.22426606], Accuracy: 49.8
# Epoch 19 complete. Total cost: [ 376.08401223], Accuracy: 49.86666666666667
# Training dataset: noisy_moons
# Epoch 0 complete. Total cost: [ 376.46299323], Accuracy: 78.46666666666667
# Epoch 1 complete. Total cost: [ 280.83764538], Accuracy: 86.0
# Epoch 2 complete. Total cost: [ 239.39047943], Accuracy: 86.73333333333333
# Epoch 3 complete. Total cost: [ 214.78239719], Accuracy: 86.86666666666666
# Epoch 4 complete. Total cost: [ 199.7080566], Accuracy: 86.86666666666666
# Epoch 5 complete. Total cost: [ 190.25678272], Accuracy: 86.73333333333333
# Epoch 6 complete. Total cost: [ 183.64173049], Accuracy: 86.4
# Epoch 7 complete. Total cost: [ 179.16492192], Accuracy: 86.86666666666666
# Epoch 8 complete. Total cost: [ 175.76746608], Accuracy: 86.86666666666666
# Epoch 9 complete. Total cost: [ 172.9858276], Accuracy: 87.0
# Epoch 10 complete. Total cost: [ 170.93156811], Accuracy: 87.0
# Epoch 11 complete. Total cost: [ 169.12344219], Accuracy: 87.2
# Epoch 12 complete. Total cost: [ 167.62132715], Accuracy: 87.33333333333333
# Epoch 13 complete. Total cost: [ 166.33363646], Accuracy: 87.0
# Epoch 14 complete. Total cost: [ 165.31054611], Accuracy: 87.4
# Epoch 15 complete. Total cost: [ 164.26242754], Accuracy: 87.0
# Epoch 16 complete. Total cost: [ 163.56392947], Accuracy: 87.33333333333333
# Epoch 17 complete. Total cost: [ 162.78746112], Accuracy: 87.53333333333333
# Epoch 18 complete. Total cost: [ 162.13566458], Accuracy: 87.53333333333333
# Epoch 19 complete. Total cost: [ 161.52230537], Accuracy: 87.8
# Training dataset: blobs
# Epoch 0 complete. Total cost: [ 617.42039664], Accuracy: 20.666666666666668
# Epoch 1 complete. Total cost: [ 473.39963702], Accuracy: 40.733333333333334
# Epoch 2 complete. Total cost: [ 381.872008], Accuracy: 43.266666666666666
# Epoch 3 complete. Total cost: [ 325.16543768], Accuracy: 42.733333333333334
# Epoch 4 complete. Total cost: [ 292.31701654], Accuracy: 93.33333333333333
# Epoch 5 complete. Total cost: [ 271.63869098], Accuracy: 100.0
# Epoch 6 complete. Total cost: [ 256.77314629], Accuracy: 99.86666666666666
# Epoch 7 complete. Total cost: [ 244.2465206], Accuracy: 99.53333333333333
# Epoch 8 complete. Total cost: [ 232.19430384], Accuracy: 99.86666666666666
# Epoch 9 complete. Total cost: [ 219.93824972], Accuracy: 98.6
# Epoch 10 complete. Total cost: [ 207.19696596], Accuracy: 99.73333333333333
# Epoch 11 complete. Total cost: [ 193.26424797], Accuracy: 100.0
# Epoch 12 complete. Total cost: [ 178.42344526], Accuracy: 100.0
# Epoch 13 complete. Total cost: [ 162.69776784], Accuracy: 99.93333333333334
# Epoch 14 complete. Total cost: [ 147.04773465], Accuracy: 100.0
# Epoch 15 complete. Total cost: [ 131.5061059], Accuracy: 100.0
# Epoch 16 complete. Total cost: [ 116.80869255], Accuracy: 100.0
# Epoch 17 complete. Total cost: [ 103.34765282], Accuracy: 100.0
# Epoch 18 complete. Total cost: [ 91.34694979], Accuracy: 100.0
# Epoch 19 complete. Total cost: [ 80.7996792], Accuracy: 100.0
# Training dataset: linearly_separable
# Epoch 0 complete. Total cost: [ 406.61740164], Accuracy: 81.8
# Epoch 1 complete. Total cost: [ 304.98546519], Accuracy: 86.66666666666667
# Epoch 2 complete. Total cost: [ 257.73536352], Accuracy: 88.33333333333333
# Epoch 3 complete. Total cost: [ 218.71441741], Accuracy: 88.0
# Epoch 4 complete. Total cost: [ 190.29135305], Accuracy: 88.6
# Epoch 5 complete. Total cost: [ 170.84172494], Accuracy: 88.53333333333333
# Epoch 6 complete. Total cost: [ 158.14407451], Accuracy: 88.4
# Epoch 7 complete. Total cost: [ 149.44645593], Accuracy: 89.06666666666666
# Epoch 8 complete. Total cost: [ 143.71928725], Accuracy: 88.66666666666667
# Epoch 9 complete. Total cost: [ 139.61146381], Accuracy: 88.66666666666667
# Epoch 10 complete. Total cost: [ 136.54445565], Accuracy: 88.8
# Epoch 11 complete. Total cost: [ 134.25065181], Accuracy: 88.66666666666667
# Epoch 12 complete. Total cost: [ 132.61050056], Accuracy: 88.66666666666667
# Epoch 13 complete. Total cost: [ 131.25256231], Accuracy: 88.73333333333333
# Epoch 14 complete. Total cost: [ 130.1765578], Accuracy: 88.66666666666667
# Epoch 15 complete. Total cost: [ 129.32150858], Accuracy: 88.66666666666667
# Epoch 16 complete. Total cost: [ 128.64257343], Accuracy: 88.8
# Epoch 17 complete. Total cost: [ 128.04662872], Accuracy: 88.66666666666667
# Epoch 18 complete. Total cost: [ 127.59473275], Accuracy: 88.66666666666667
# Epoch 19 complete. Total cost: [ 127.24406526], Accuracy: 88.66666666666667
# Training dataset: aniso
# Epoch 0 complete. Total cost: [ 514.79791908], Accuracy: 67.2
# Epoch 1 complete. Total cost: [ 334.19012184], Accuracy: 93.46666666666667
# Epoch 2 complete. Total cost: [ 280.24923772], Accuracy: 94.2
# Epoch 3 complete. Total cost: [ 253.8617473], Accuracy: 92.46666666666667
# Epoch 4 complete. Total cost: [ 236.07969518], Accuracy: 93.73333333333333
# Epoch 5 complete. Total cost: [ 222.121107], Accuracy: 94.13333333333334
# Epoch 6 complete. Total cost: [ 210.30583843], Accuracy: 93.06666666666666
# Epoch 7 complete. Total cost: [ 199.63640207], Accuracy: 92.8
# Epoch 8 complete. Total cost: [ 190.18445556], Accuracy: 93.26666666666667
# Epoch 9 complete. Total cost: [ 181.62675526], Accuracy: 93.2
# Epoch 10 complete. Total cost: [ 173.54146772], Accuracy: 93.0
# Epoch 11 complete. Total cost: [ 166.05467206], Accuracy: 93.8
# Epoch 12 complete. Total cost: [ 159.21648548], Accuracy: 93.46666666666667
# Epoch 13 complete. Total cost: [ 152.95391747], Accuracy: 93.73333333333333
# Epoch 14 complete. Total cost: [ 147.2783691], Accuracy: 93.66666666666667
# Epoch 15 complete. Total cost: [ 141.80994582], Accuracy: 94.6
# Epoch 16 complete. Total cost: [ 137.20656643], Accuracy: 93.93333333333334
# Epoch 17 complete. Total cost: [ 132.59035895], Accuracy: 94.2
# Epoch 18 complete. Total cost: [ 128.42965364], Accuracy: 94.4
# Epoch 19 complete. Total cost: [ 124.56435644], Accuracy: 94.2
# Training dataset: varied
# Epoch 0 complete. Total cost: [ 410.33380698], Accuracy: 84.06666666666666
# Epoch 1 complete. Total cost: [ 348.67138492], Accuracy: 83.6
# Epoch 2 complete. Total cost: [ 306.08281359], Accuracy: 84.6
# Epoch 3 complete. Total cost: [ 274.93257499], Accuracy: 84.4
# Epoch 4 complete. Total cost: [ 251.60317308], Accuracy: 84.8
# Epoch 5 complete. Total cost: [ 234.00353643], Accuracy: 86.73333333333333
# Epoch 6 complete. Total cost: [ 220.35211295], Accuracy: 87.53333333333333
# Epoch 7 complete. Total cost: [ 209.58109833], Accuracy: 88.0
# Epoch 8 complete. Total cost: [ 200.82439722], Accuracy: 89.33333333333333
# Epoch 9 complete. Total cost: [ 193.78515831], Accuracy: 89.13333333333334
# Epoch 10 complete. Total cost: [ 187.7680615], Accuracy: 88.86666666666666
# Epoch 11 complete. Total cost: [ 182.6585849], Accuracy: 89.33333333333333
# Epoch 12 complete. Total cost: [ 178.25374778], Accuracy: 89.66666666666667
# Epoch 13 complete. Total cost: [ 174.39663001], Accuracy: 89.8
# Epoch 14 complete. Total cost: [ 171.03342515], Accuracy: 89.66666666666667
# Epoch 15 complete. Total cost: [ 168.04941209], Accuracy: 89.66666666666667
# Epoch 16 complete. Total cost: [ 165.39971708], Accuracy: 89.66666666666667
# Epoch 17 complete. Total cost: [ 163.02595266], Accuracy: 89.73333333333333
# Epoch 18 complete. Total cost: [ 160.89123562], Accuracy: 89.8
# Epoch 19 complete. Total cost: [ 158.9403955], Accuracy: 89.86666666666666

# %%
plot_datasets(datasets_with_pred)
